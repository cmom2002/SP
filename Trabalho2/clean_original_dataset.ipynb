# %%
import random
import pandas as pd

# %%
path = "dataset/netflix_titles.csv"
file = pd.read_csv(path)
df = pd.DataFrame(file)
display(df)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
for i in range(len(df)):
    tipo = df["type"][i]
    if tipo == "TV Show":
        index_line = df.index[df["type"] == tipo].tolist()[0]
        df = df.drop(index_line)

df = df.drop("type", axis=1)       
df.to_csv("dataset/netflix_1.csv", index=False)

# %%
path = "dataset/netflix_1.csv"
file = pd.read_csv(path)
df = pd.DataFrame(file)
display(df)
# Out:
#      show_id                             title                       director  \
# 0         s1              Dick Johnson Is Dead                Kirsten Johnson
# 1         s7  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 2         s8                           Sankofa                   Haile Gerima
# 3        s10                      The Starling                 Theodore Melfi
# 4        s13                      Je Suis Karl            Christian Schwochow
# ...      ...                               ...                            ...
# 6126   s8802                           Zinzana                Majid Al Ansari
# 6127   s8803                            Zodiac                  David Fincher
# 6128   s8805                        Zombieland                Ruben Fleischer
# 6129   s8806                              Zoom                   Peter Hewitt
# 6130   s8807                            Zubaan                    Mozez Singh
#
# ...

# %%
for i in range(len(df)):   
    rating = random.randint(1, 5)
    df["rating"][i] = rating
    genero = df["listed_in"][i]
    if "," in genero:
        df["listed_in"][i] = genero.split(",")[0]

df.to_csv("dataset/netflix_final.csv", index=False)
display(df)
# Out:
# C:\Users\alfre\AppData\Local\Temp\ipykernel_7836\907941985.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rating"][i] = rating
# C:\Users\alfre\AppData\Local\Temp\ipykernel_7836\907941985.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rating"][i] = rating
# C:\Users\alfre\AppData\Local\Temp\ipykernel_7836\907941985.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rating"][i] = rating
# ...

# %%
path = "dataset/netflix_final.csv"
file = pd.read_csv(path)
df = pd.DataFrame(file)
display(df)
# Out:
#      show_id                             Filme                     Realizador  \
# 0         s1              Dick Johnson Is Dead                Kirsten Johnson
# 1         s7  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 2         s8                           Sankofa                   Haile Gerima
# 3        s10                      The Starling                 Theodore Melfi
# 4        s13                      Je Suis Karl            Christian Schwochow
# ...      ...                               ...                            ...
# 6126   s8802                           Zinzana                Majid Al Ansari
# 6127   s8803                            Zodiac                  David Fincher
# 6128   s8805                        Zombieland                Ruben Fleischer
# 6129   s8806                              Zoom                   Peter Hewitt
# 6130   s8807                            Zubaan                    Mozez Singh
#
# ...

# %%
df = df.drop(["show_id", "cast", "country", "date_added", "description"], axis=1)
display(df)
df.to_csv("dataset/netflix_final_final.csv", index=False)
# Out:
#                                  Filme                     Realizador  \
# 0                 Dick Johnson Is Dead                Kirsten Johnson
# 1     My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 2                              Sankofa                   Haile Gerima
# 3                         The Starling                 Theodore Melfi
# 4                         Je Suis Karl            Christian Schwochow
# ...                                ...                            ...
# 6126                           Zinzana                Majid Al Ansari
# 6127                            Zodiac                  David Fincher
# 6128                        Zombieland                Ruben Fleischer
# 6129                              Zoom                   Peter Hewitt
# 6130                            Zubaan                    Mozez Singh
#
#       Ano lancamento  Rating  Duracao                    Genero
# ...
