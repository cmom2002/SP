# %%
import numpy as np
import pandas as pd

file = pd.read_csv('fertility.csv')

# %%
file
# Out:
#     Season  Age Childish diseases Accident or serious trauma  \
# 0   spring   30                no                        yes
# 1   spring   35               yes                         no
# 2   spring   27               yes                         no
# 3   spring   32                no                        yes
# 4   spring   30               yes                        yes
# ..     ...  ...               ...                        ...
# 95  winter   30               yes                         no
# 96  winter   29               yes                         no
# 97  winter   30               yes                        yes
# 98  winter   30               yes                         no
# 99  winter   30                no                        yes
#
#    Surgical intervention High fevers in the last year  \
# 0                    yes       more than 3 months ago
# 1                    yes       more than 3 months ago
# 2                     no       more than 3 months ago
# ...

# %% [markdown]
# #### Generate 1400 rows of data

# %%
import random

rows = 1400

# Create a dictionary to store the unique values for each column
values = {
    'Season': file['Season'].unique(),
    'Age': file['Age'].unique(),
    'Childish diseases': file['Childish diseases'].unique(),
    'Accident or serious trauma': file['Accident or serious trauma'].unique(),
    'Surgical intervention': file['Surgical intervention'].unique(),
    'High fevers in the last year': file['High fevers in the last year'].unique(),
    'Frequency of alcohol consumption': file['Frequency of alcohol consumption'].unique(),
    'Smoking habit': file['Smoking habit'].unique(),
    'Number of hours spent sitting per day': file['Number of hours spent sitting per day'].unique(),
    'Diagnosis': file['Diagnosis'].unique()
}

# Generate additional rows with random combinations of unique values
data = []
for _ in range(rows):
    row = {
        'Season': random.choice(values['Season']),
        'Age': random.choice(values['Age']),
        'Childish diseases': random.choice(values['Childish diseases']),
        'Accident or serious trauma': random.choice(values['Accident or serious trauma']),
        'Surgical intervention': random.choice(values['Surgical intervention']),
        'High fevers in the last year': random.choice(values['High fevers in the last year']),
        'Frequency of alcohol consumption': random.choice(values['Frequency of alcohol consumption']),
        'Smoking habit': random.choice(values['Smoking habit']),
        'Number of hours spent sitting per day': random.choice(values['Number of hours spent sitting per day']),
        'Diagnosis': random.choice(values['Diagnosis'])
    }
    data.append(row)

# Create a new DataFrame with the original data and the generated data
new_file = pd.concat([file, pd.DataFrame(data)], ignore_index=True)

# The 'new_df' DataFrame now contains the original data plus 1400 additional rows with random combinations of unique values.

# %%
column_data_types = new_file.dtypes

# Print the data types of each column
print(column_data_types)
# Out:
# Season                                   object
# Age                                       int64
# Childish diseases                        object
# Accident or serious trauma               object
# Surgical intervention                    object
# High fevers in the last year             object
# Frequency of alcohol consumption         object
# Smoking habit                            object
# Number of hours spent sitting per day     int64
# Diagnosis                                object
# dtype: object

# %%
# Export new dataset to csv
new_file.to_csv('output_file.csv', index=False)

# %%
new_file
# Out:
#       Season  Age Childish diseases Accident or serious trauma  \
# 0     spring   30                no                        yes
# 1     spring   35               yes                         no
# 2     spring   27               yes                         no
# 3     spring   32                no                        yes
# 4     spring   30               yes                        yes
# ...      ...  ...               ...                        ...
# 1495  winter   27                no                        yes
# 1496    fall   28                no                        yes
# 1497  summer   35                no                        yes
# 1498  spring   29               yes                         no
# 1499    fall   36                no                        yes
#
#      Surgical intervention High fevers in the last year  \
# 0                      yes       more than 3 months ago
# 1                      yes       more than 3 months ago
# ...
