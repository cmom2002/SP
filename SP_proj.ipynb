# %%
import numpy as np
import pandas as pd
import random

file = pd.read_csv('fertility.csv')

# %%
file
# Out:
#     Season  Age Childish diseases Accident or serious trauma  \
# 0   spring   30                no                        yes
# 1   spring   35               yes                         no
# 2   spring   27               yes                         no
# 3   spring   32                no                        yes
# 4   spring   30               yes                        yes
# ..     ...  ...               ...                        ...
# 95  winter   30               yes                         no
# 96  winter   29               yes                         no
# 97  winter   30               yes                        yes
# 98  winter   30               yes                         no
# 99  winter   30                no                        yes
#
#    Surgical intervention High fevers in the last year  \
# 0                    yes       more than 3 months ago
# 1                    yes       more than 3 months ago
# 2                     no       more than 3 months ago
# 3                    yes       more than 3 months ago
# 4                     no       more than 3 months ago
# ..                   ...                          ...
# 95                    no       more than 3 months ago
# 96                    no       more than 3 months ago
# 97                   yes       more than 3 months ago
# 98                   yes       more than 3 months ago
# 99                   yes       more than 3 months ago
#
#    Frequency of alcohol consumption Smoking habit  \
# 0                       once a week    occasional
# 1                       once a week         daily
# 2              hardly ever or never         never
# 3              hardly ever or never         never
# 4                       once a week         never
# ..                              ...           ...
# 95             hardly ever or never         never
# 96                      once a week    occasional
# 97             hardly ever or never         never
# 98             hardly ever or never    occasional
# 99             several times a week         never
#
#     Number of hours spent sitting per day Diagnosis
# 0                                      16    Normal
# 1                                       6   Altered
# 2                                       9    Normal
# 3                                       7    Normal
# 4                                       9   Altered
# ..                                    ...       ...
# 95                                      9    Normal
# 96                                      9    Normal
# 97                                      6    Normal
# 98                                      3    Normal
# 99                                      3    Normal
#
# [100 rows x 10 columns]

# %% [markdown]
# # Treatment of the dataset

# %%
file.rename(columns={'Diagnosis' : 'Blood sample results'}, inplace=True)
file.drop(columns=['High fevers in the last year', 'Number of hours spent sitting per day', 'Season'],
           inplace=True)

# %%
file
# Out:
#     Age Childish diseases Accident or serious trauma Surgical intervention  \
# 0    30                no                        yes                   yes
# 1    35               yes                         no                   yes
# 2    27               yes                         no                    no
# 3    32                no                        yes                   yes
# 4    30               yes                        yes                    no
# ..  ...               ...                        ...                   ...
# 95   30               yes                         no                    no
# 96   29               yes                         no                    no
# 97   30               yes                        yes                   yes
# 98   30               yes                         no                   yes
# 99   30                no                        yes                   yes
#
#    Frequency of alcohol consumption Smoking habit Blood sample results
# 0                       once a week    occasional               Normal
# 1                       once a week         daily              Altered
# 2              hardly ever or never         never               Normal
# 3              hardly ever or never         never               Normal
# 4                       once a week         never              Altered
# ..                              ...           ...                  ...
# 95             hardly ever or never         never               Normal
# 96                      once a week    occasional               Normal
# 97             hardly ever or never         never               Normal
# 98             hardly ever or never    occasional               Normal
# 99             several times a week         never               Normal
#
# [100 rows x 7 columns]

# %%
cc = 10000000

race = ["White non-Hispanic", "Asian", "Hispanic (of any race)", "Caucasian", "Black"]

eye_color = ["Black", "Brown", "Green", "Blue"]

height = [140, 230]

weight = [40, 150]

sperm_quality = ["High", "Average", "Low"]

degree = ["12 grade", "Banchelor", "Master", "PhD", "Other"]

job = ["Doctor", "Teacher", "Engineer", "Nurse", "Lawyer", "Programmer", "Dentist", "Architect", "Artist",
       "Chef", "Scientist", "Police officer", "Firefighter", "Writer", "Musician", "Accountant", "Pharmacist",
       "Mechanic", "Designer", "Veterinarian", "Electrician", "Plumber", "Actor", "Journalist", "Librarian",
       "Psychologist", "Pilot", "Singer", "Paramedic", "Physician", "Phlebotomist", "Truck driver", "Farmer", 
       "Chemist", "Surgeon", "Veterinary technician", "Waiter/waitress", "Hairdresser", "Banker", "graphic designer",
]

genetic_result = ["Normal", "Altered"]
orientation = ["Heterosexual", "Homosexual", "Bisexual", "Pansexual", "Asexual", "Demisexual", "Queer", "Questioning",
               "Polysexual", "Androgynosexual", "Skoliosexual", "Sapiosexual", "Autosexual", "Graysexual", "Aromantic",
               "Biromantic", "Homoromantic", "Panromantic", "Demiromantic", "Lithromantic",
]

# %%
rows = 100

more_columns = file.assign(
    cl1 = [cc + i * 7 for i in range(100)],
    cl2 = [random.choice(race) for i in range(100)],
    cl3 = [random.choice(eye_color) for i in range(100)],
    cl4 = [random.randint(height[0], height[1]) for i in range(100)],
    cl5 = [random.randint(weight[0], weight[1]) for i in range(100)],
    cl6 = [random.choice(sperm_quality) for i in range(100)],
    cl7 = [random.choice(degree) for i in range(100)],
    cl8 = [random.choice(job) for i in range(100)],
    cl9 = [random.choice(genetic_result) for i in range(100)],
    cl10 = [random.choice(orientation) for i in range(100)]
)

more_columns.rename(columns={'cl1' : 'Identification number', 'cl2' : 'Race', 'cl3' : 'Eye color', 'cl4' : 'Height', 'cl5' : 'Weight', 'cl6' : 'Sperm quality', 'cl7' : 'Degree', 'cl8' : 'Job', 'cl9' : 'Genetic results', 'cl10' : 'Sexual Orientation'}, inplace=True)

# %%
#more_columns.to_csv('all_columns.csv', index=False)
more_columns
# Out:
#     Age Childish diseases Accident or serious trauma Surgical intervention  \
# 0    30                no                        yes                   yes
# 1    35               yes                         no                   yes
# 2    27               yes                         no                    no
# 3    32                no                        yes                   yes
# 4    30               yes                        yes                    no
# ..  ...               ...                        ...                   ...
# 95   30               yes                         no                    no
# 96   29               yes                         no                    no
# 97   30               yes                        yes                   yes
# 98   30               yes                         no                   yes
# 99   30                no                        yes                   yes
#
#    Frequency of alcohol consumption Smoking habit Blood sample results  \
# 0                       once a week    occasional               Normal
# 1                       once a week         daily              Altered
# 2              hardly ever or never         never               Normal
# 3              hardly ever or never         never               Normal
# 4                       once a week         never              Altered
# ..                              ...           ...                  ...
# 95             hardly ever or never         never               Normal
# 96                      once a week    occasional               Normal
# 97             hardly ever or never         never               Normal
# 98             hardly ever or never    occasional               Normal
# 99             several times a week         never               Normal
#
#     Identification number                    Race Eye color  Height  Weight  \
# 0                10000000  Hispanic (of any race)     Black     156     144
# 1                10000007               Caucasian     Brown     159      61
# 2                10000014               Caucasian      Blue     223     120
# 3                10000021      White non-Hispanic     Black     163      47
# 4                10000028      White non-Hispanic     Green     208      76
# ..                    ...                     ...       ...     ...     ...
# 95               10000665                   Asian     Brown     183     112
# 96               10000672                   Asian      Blue     215     128
# 97               10000679  Hispanic (of any race)     Black     215      44
# 98               10000686  Hispanic (of any race)     Brown     207      57
# 99               10000693                   Asian     Brown     208     138
#
#    Sperm quality     Degree             Job Genetic results Sexual Orientation
# 0        Average        PhD       Librarian          Normal         Polysexual
# 1        Average     Master          Singer         Altered              Queer
# 2        Average   12 grade      Pharmacist          Normal       Skoliosexual
# 3        Average      Other        Engineer         Altered         Biromantic
# 4            Low      Other  Police officer         Altered       Homoromantic
# ..           ...        ...             ...             ...                ...
# 95          High  Banchelor     Hairdresser          Normal           Bisexual
# 96          High        PhD     Hairdresser         Altered            Asexual
# 97           Low      Other         Dentist         Altered        Questioning
# 98           Low        PhD       Physician          Normal    Androgynosexual
# 99       Average        PhD          Lawyer         Altered    Androgynosexual
#
# [100 rows x 17 columns]

# %% [markdown]
# #### Generate 1400 rows of data

# %%
#all_columns = pd.read_csv('all_columns.csv')

rows = 1400

values = {
    'Age': file['Age'].unique(),
    'Childish diseases': file['Childish diseases'].unique(),
    'Accident or serious trauma': file['Accident or serious trauma'].unique(),
    'Surgical intervention': file['Surgical intervention'].unique(),
    'Frequency of alcohol consumption': file['Frequency of alcohol consumption'].unique(),
    'Smoking habit': file['Smoking habit'].unique(),
    'Blood sample results': file['Blood sample results'].unique()
}


data = []
for i in range(rows):
    row = {
        'Age': random.choice(values['Age']),
        'Childish diseases': random.choice(values['Childish diseases']),
        'Accident or serious trauma': random.choice(values['Accident or serious trauma']),
        'Surgical intervention': random.choice(values['Surgical intervention']),
        'Frequency of alcohol consumption': random.choice(values['Frequency of alcohol consumption']),
        'Smoking habit': random.choice(values['Smoking habit']),
        'Blood sample results': random.choice(values['Blood sample results']),
        'Identification number' : cc,
        'Race' : random.choice(race),
        'Eye color' : random.choice(eye_color),
        'Height' : random.randint(height[0], height[1]), 
        'Weight' : random.randint(weight[0], weight[1]), 
        'Sperm quality': random.choice(sperm_quality), 
        'Degree' : random.choice(degree), 
        'Job' : random.choice(job), 
        'Genetic results' : random.choice(genetic_result), 
        'Sexual Orientation' : random.choice(orientation)
    }
    cc += 10
    data.append(row)

new_file = pd.concat([more_columns, pd.DataFrame(data)], ignore_index=True)

new_file.to_csv('dataset_with_1500_rows.csv', index=False)

# %%
new_file
# Out:
#       Age Childish diseases Accident or serious trauma Surgical intervention  \
# 0      30                no                        yes                   yes
# 1      35               yes                         no                   yes
# 2      27               yes                         no                    no
# 3      32                no                        yes                   yes
# 4      30               yes                        yes                    no
# ...   ...               ...                        ...                   ...
# 1495   29               yes                         no                    no
# 1496   27                no                        yes                    no
# 1497   33               yes                         no                    no
# 1498   35                no                        yes                    no
# 1499   27               yes                        yes                   yes
#
#      Frequency of alcohol consumption Smoking habit Blood sample results  \
# 0                         once a week    occasional               Normal
# 1                         once a week         daily              Altered
# 2                hardly ever or never         never               Normal
# 3                hardly ever or never         never               Normal
# 4                         once a week         never              Altered
# ...                               ...           ...                  ...
# 1495                        every day    occasional              Altered
# 1496             hardly ever or never         daily               Normal
# 1497                      once a week         daily               Normal
# 1498             hardly ever or never         daily              Altered
# 1499             several times a week         daily               Normal
#
#       Identification number                    Race Eye color  Height  Weight  \
# 0                  10000000  Hispanic (of any race)     Black     156     144
# 1                  10000007               Caucasian     Brown     159      61
# 2                  10000014               Caucasian      Blue     223     120
# 3                  10000021      White non-Hispanic     Black     163      47
# 4                  10000028      White non-Hispanic     Green     208      76
# ...                     ...                     ...       ...     ...     ...
# 1495               10013950                   Black      Blue     196     106
# 1496               10013960      White non-Hispanic      Blue     153     114
# 1497               10013970                   Black      Blue     215      87
# 1498               10013980                   Asian     Brown     209     118
# 1499               10013990                   Asian     Black     165     112
#
#      Sperm quality    Degree             Job Genetic results  \
# 0          Average       PhD       Librarian          Normal
# 1          Average    Master          Singer         Altered
# 2          Average  12 grade      Pharmacist          Normal
# 3          Average     Other        Engineer         Altered
# 4              Low     Other  Police officer         Altered
# ...            ...       ...             ...             ...
# 1495          High       PhD          Doctor          Normal
# 1496       Average    Master     Hairdresser          Normal
# 1497           Low    Master         Chemist          Normal
# 1498           Low  12 grade    Veterinarian          Normal
# 1499       Average       PhD          Banker         Altered
#
#      Sexual Orientation
# 0            Polysexual
# 1                 Queer
# 2          Skoliosexual
# 3            Biromantic
# 4          Homoromantic
# ...                 ...
# 1495          Pansexual
# 1496          Aromantic
# 1497         Homosexual
# 1498    Androgynosexual
# 1499       Homoromantic
#
# [1500 rows x 17 columns]
