# %%
import numpy as np
import pandas as pd
import random

file = pd.read_csv('fertility.csv')

# %%
file
# Out:
#     Season  Age Childish diseases Accident or serious trauma  \
# 0   spring   30                no                        yes
# 1   spring   35               yes                         no
# 2   spring   27               yes                         no
# 3   spring   32                no                        yes
# 4   spring   30               yes                        yes
# ..     ...  ...               ...                        ...
# 95  winter   30               yes                         no
# 96  winter   29               yes                         no
# 97  winter   30               yes                        yes
# 98  winter   30               yes                         no
# 99  winter   30                no                        yes
#
#    Surgical intervention High fevers in the last year  \
# 0                    yes       more than 3 months ago
# 1                    yes       more than 3 months ago
# 2                     no       more than 3 months ago
# 3                    yes       more than 3 months ago
# 4                     no       more than 3 months ago
# ..                   ...                          ...
# 95                    no       more than 3 months ago
# 96                    no       more than 3 months ago
# 97                   yes       more than 3 months ago
# 98                   yes       more than 3 months ago
# 99                   yes       more than 3 months ago
#
#    Frequency of alcohol consumption Smoking habit  \
# 0                       once a week    occasional
# 1                       once a week         daily
# 2              hardly ever or never         never
# 3              hardly ever or never         never
# 4                       once a week         never
# ..                              ...           ...
# 95             hardly ever or never         never
# 96                      once a week    occasional
# 97             hardly ever or never         never
# 98             hardly ever or never    occasional
# 99             several times a week         never
#
#     Number of hours spent sitting per day Diagnosis
# 0                                      16    Normal
# 1                                       6   Altered
# 2                                       9    Normal
# 3                                       7    Normal
# 4                                       9   Altered
# ..                                    ...       ...
# 95                                      9    Normal
# 96                                      9    Normal
# 97                                      6    Normal
# 98                                      3    Normal
# 99                                      3    Normal
#
# [100 rows x 10 columns]

# %% [markdown]
# # Treatment of the dataset

# %%
file.rename(columns={'Diagnosis' : 'Blood sample results'}, inplace=True)
file.drop(columns=['High fevers in the last year', 'Number of hours spent sitting per day', 'Season'],
           inplace=True)

# %%
file
# Out:
#     Age Childish diseases Accident or serious trauma Surgical intervention  \
# 0    30                no                        yes                   yes
# 1    35               yes                         no                   yes
# 2    27               yes                         no                    no
# 3    32                no                        yes                   yes
# 4    30               yes                        yes                    no
# ..  ...               ...                        ...                   ...
# 95   30               yes                         no                    no
# 96   29               yes                         no                    no
# 97   30               yes                        yes                   yes
# 98   30               yes                         no                   yes
# 99   30                no                        yes                   yes
#
#    Frequency of alcohol consumption Smoking habit Blood sample results
# 0                       once a week    occasional               Normal
# 1                       once a week         daily              Altered
# 2              hardly ever or never         never               Normal
# 3              hardly ever or never         never               Normal
# 4                       once a week         never              Altered
# ..                              ...           ...                  ...
# 95             hardly ever or never         never               Normal
# 96                      once a week    occasional               Normal
# 97             hardly ever or never         never               Normal
# 98             hardly ever or never    occasional               Normal
# 99             several times a week         never               Normal
#
# [100 rows x 7 columns]

# %%
cc = 10000000

race = ["white non-Hispanic", "asian", "hispanic (of any race)", "caucasian", "black"]

eye_color = ["black", "brown", "green", "blue"]

height = [140, 230]

weight = [40, 150]

sperm_quality = ["high", "average", "low"]

degree = ["12 grade", "banchelor", "master", "phD", "other"]

job = ["doctor", "teacher", "engineer", "nurse", "lawyer", "programmer", "dentist", "architect", "artist",
       "chef", "scientist", "police officer", "firefighter", "writer", "musician", "accountant", "pharmacist",
       "mechanic", "designer", "veterinarian", "electrician", "plumber", "actor", "journalist", "librarian",
       "psychologist", "pilot", "singer", "paramedic", "physician", "phlebotomist", "truck driver", "farmer", 
       "chemist", "surgeon", "veterinary technician", "waiter/waitress", "fairdresser", "banker", "graphic designer"
]

genetic_result = ["normal", "altered"]

orientation = ["pansexual", "asexual", "demisexual", "queer", "questioning",
               "polysexual", "androgynosexual", "skoliosexual", "sapiosexual", "autosexual", "graysexual", "aromantic",
               "biromantic", "homoromantic", "panromantic", "demiromantic", "lithromantic"
]

psyc_evaluation = ["passed", "failed"]

# %%
rows = len(file)

os = []

for i in range(rows):
    r = random.randint(1, 100)
    if r <= 80:
        os.append("heterosexual")
    elif r > 80 and r <= 90:
        os.append("homosexual")
    elif r > 90 and r <= 95:
        os.append("bisexual")
    else:
        os.append(random.choice(orientation))

p = []
for i in range(rows):
    preocupations = ["animal abuse", "racism", "machismo", "homophobia", "global warming", "xenophobia"]

    r = random.randint(0, len(preocupations))
    string = ''
    for i in range(r):
        choice = random.choice(preocupations)
        if i == r - 1:
            string += choice
        else:
            string += choice + ', '
        preocupations.pop(preocupations.index(choice))
    p.append(string)

more_columns = file.assign(
    cl1 = [cc + i * 7 for i in range(100)],
    cl2 = [random.choice(race) for _ in range(100)],
    cl3 = [random.choice(eye_color) for _ in range(100)],
    cl4 = [random.randint(height[0], height[1]) for _ in range(100)],
    cl5 = [random.randint(weight[0], weight[1]) for _ in range(100)],
    cl6 = [random.choice(sperm_quality) for _ in range(100)],
    cl7 = [random.choice(degree) for _ in range(100)],
    cl8 = [random.choice(job) for _ in range(100)],
    cl9 = [random.choice(genetic_result) for _ in range(100)],
    cl10 = [random.choice(psyc_evaluation) for _ in range(100)],
    cl11 = os,
    cl12 = p
)

    

more_columns.rename(columns={'cl1' : 'Health number', 'cl2' : 'Race', 'cl3' : 'Eye color', 'cl4' : 'Height', 'cl5' : 'Weight', 'cl6' : 'Sperm quality', 'cl7' : 'Degree', 'cl8' : 'Job', 'cl9' : 'Genetic results', 'cl10' : 'Psycological evaluation', 'cl11' : 'Sexual orientation', 'cl12' : 'Preocupations'}, inplace=True)

# %%
more_columns
# Out:
#     Age Childish diseases Accident or serious trauma Surgical intervention  \
# 0    30                no                        yes                   yes
# 1    35               yes                         no                   yes
# 2    27               yes                         no                    no
# 3    32                no                        yes                   yes
# 4    30               yes                        yes                    no
# ..  ...               ...                        ...                   ...
# 95   30               yes                         no                    no
# 96   29               yes                         no                    no
# 97   30               yes                        yes                   yes
# 98   30               yes                         no                   yes
# 99   30                no                        yes                   yes
#
#    Frequency of alcohol consumption Smoking habit Blood sample results  \
# 0                       once a week    occasional               Normal
# 1                       once a week         daily              Altered
# 2              hardly ever or never         never               Normal
# 3              hardly ever or never         never               Normal
# 4                       once a week         never              Altered
# ..                              ...           ...                  ...
# 95             hardly ever or never         never               Normal
# 96                      once a week    occasional               Normal
# 97             hardly ever or never         never               Normal
# 98             hardly ever or never    occasional               Normal
# 99             several times a week         never               Normal
#
#     Health number                    Race Eye color  Height  Weight  \
# 0        10000000  hispanic (of any race)     black     171     119
# 1        10000007  hispanic (of any race)     brown     179      58
# 2        10000014  hispanic (of any race)     black     169      61
# 3        10000021                   black     black     145      49
# 4        10000028  hispanic (of any race)     brown     198      48
# ..            ...                     ...       ...     ...     ...
# 95       10000665                   black     brown     148      68
# 96       10000672                   black      blue     209     109
# 97       10000679      white non-Hispanic      blue     200     102
# 98       10000686                   asian      blue     147      45
# 99       10000693  hispanic (of any race)     black     182      60
#
#    Sperm quality    Degree              Job Genetic results  \
# 0            low       phD         mechanic          normal
# 1        average    master            actor          normal
# 2        average  12 grade        physician         altered
# 3            low    master          surgeon          normal
# 4            low    master  waiter/waitress         altered
# ..           ...       ...              ...             ...
# 95           low       phD         designer          normal
# 96           low  12 grade         mechanic          normal
# 97       average       phD       programmer         altered
# 98          high     other        physician          normal
# 99           low    master       journalist          normal
#
#    Psycological evaluation Sexual orientation  \
# 0                   failed         homosexual
# 1                   failed       heterosexual
# 2                   failed       heterosexual
# 3                   failed       heterosexual
# 4                   failed       heterosexual
# ..                     ...                ...
# 95                  passed       heterosexual
# 96                  passed         homosexual
# 97                  failed       heterosexual
# 98                  passed       heterosexual
# 99                  passed       heterosexual
#
#                                         Preocupations
# 0   animal abuse, machismo, xenophobia, racism, ho...
# 1                      racism, machismo, animal abuse
# 2   machismo, racism, global warming, animal abuse...
# 3
# 4                              animal abuse, machismo
# ..                                                ...
# 95  xenophobia, machismo, animal abuse, racism, gl...
# 96  animal abuse, homophobia, global warming, raci...
# 97
# 98  global warming, homophobia, animal abuse, mach...
# 99                           global warming, machismo
#
# [100 rows x 19 columns]

# %% [markdown]
# #### Generate 1400 rows of data

# %%
rows = 1400

values = {
    'Age': file['Age'].unique(),
    'Childish diseases': file['Childish diseases'].unique(),
    'Accident or serious trauma': file['Accident or serious trauma'].unique(),
    'Surgical intervention': file['Surgical intervention'].unique(),
    'Frequency of alcohol consumption': file['Frequency of alcohol consumption'].unique(),
    'Smoking habit': file['Smoking habit'].unique(),
    'Blood sample results': file['Blood sample results'].unique()
}
print(values['Smoking habit'])


data = []
for i in range(rows):
    row = {
        'Age': random.choice(values['Age']),
        'Childish diseases': random.choice(values['Childish diseases']),
        'Accident or serious trauma': random.choice(values['Accident or serious trauma']),
        'Surgical intervention': random.choice(values['Surgical intervention']),
        'Frequency of alcohol consumption': random.choice(values['Frequency of alcohol consumption']),
        'Smoking habit': random.choice(values['Smoking habit']),
        'Blood sample results': random.choice(values['Blood sample results']),
        'Health number' : cc,
        'Race' : random.choice(race),
        'Eye color' : random.choice(eye_color),
        'Height' : random.randint(height[0], height[1]), 
        'Weight' : random.randint(weight[0], weight[1]), 
        'Sperm quality': random.choice(sperm_quality), 
        'Degree' : random.choice(degree), 
        'Job' : random.choice(job), 
        'Genetic results' : random.choice(genetic_result), 
        'Sexual orientation' : None,
        'Psycological evaluation' : random.choice(psyc_evaluation),
        'Preocupations' : None
    }
    r = random.randint(1, 100)
    if r <= 80:
        row["Sexual orientation"] = "heterosexual"
    elif r > 80 and r <= 90:
        row["Sexual orientation"] = "homosexual"
    elif r > 90 and r <= 95:
        row["Sexual orientation"] = "bisexual"
    else:
        row["Sexual orientation"] = random.choice(orientation)

    preocupations = ["animal abuse", "racism", "machismo", "homophobia", "global warming", "xenophobia"]

    r = random.randint(0, len(preocupations))
    string = ''
    for i in range(r):
        choice = random.choice(preocupations)
        if i == r - 1:
            string += choice
        else:
            string += choice + ', '
        preocupations.pop(preocupations.index(choice))
    row["Preocupations"] = string

    cc += 10
    data.append(row)



new_file = pd.concat([more_columns, pd.DataFrame(data)], ignore_index=True)

new_file.to_csv('dataset_with_1500_rows.csv', index=False)
# Out:
# ['occasional' 'daily' 'never']

# %%
new_file
# Out:
#       Age Childish diseases Accident or serious trauma Surgical intervention  \
# 0      30                no                        yes                   yes
# 1      35               yes                         no                   yes
# 2      27               yes                         no                    no
# 3      32                no                        yes                   yes
# 4      30               yes                        yes                    no
# ...   ...               ...                        ...                   ...
# 1495   36               yes                        yes                   yes
# 1496   35                no                        yes                   yes
# 1497   31               yes                        yes                    no
# 1498   29               yes                        yes                    no
# 1499   30               yes                         no                    no
#
#      Frequency of alcohol consumption Smoking habit Blood sample results  \
# 0                         once a week    occasional               Normal
# 1                         once a week         daily              Altered
# 2                hardly ever or never         never               Normal
# 3                hardly ever or never         never               Normal
# 4                         once a week         never              Altered
# ...                               ...           ...                  ...
# 1495             hardly ever or never         daily              Altered
# 1496                        every day         never               Normal
# 1497              several times a day    occasional              Altered
# 1498             hardly ever or never         daily               Normal
# 1499              several times a day         never              Altered
#
#       Health number                    Race Eye color  Height  Weight  \
# 0          10000000  hispanic (of any race)     black     171     119
# 1          10000007  hispanic (of any race)     brown     179      58
# 2          10000014  hispanic (of any race)     black     169      61
# 3          10000021                   black     black     145      49
# 4          10000028  hispanic (of any race)     brown     198      48
# ...             ...                     ...       ...     ...     ...
# 1495       10013950               caucasian     brown     201     127
# 1496       10013960               caucasian     black     148     134
# 1497       10013970                   black     brown     168     132
# 1498       10013980      white non-Hispanic     brown     167     114
# 1499       10013990               caucasian     brown     223      59
#
#      Sperm quality     Degree              Job Genetic results  \
# 0              low        phD         mechanic          normal
# 1          average     master            actor          normal
# 2          average   12 grade        physician         altered
# 3              low     master          surgeon          normal
# 4              low     master  waiter/waitress         altered
# ...            ...        ...              ...             ...
# 1495           low      other        librarian         altered
# 1496          high     master           doctor         altered
# 1497           low      other        paramedic          normal
# 1498       average      other        scientist         altered
# 1499          high  banchelor            actor         altered
#
#      Psycological evaluation Sexual orientation  \
# 0                     failed         homosexual
# 1                     failed       heterosexual
# 2                     failed       heterosexual
# 3                     failed       heterosexual
# 4                     failed       heterosexual
# ...                      ...                ...
# 1495                  failed    androgynosexual
# 1496                  failed       heterosexual
# 1497                  passed         homosexual
# 1498                  passed       heterosexual
# 1499                  passed           bisexual
#
#                                           Preocupations
# 0     animal abuse, machismo, xenophobia, racism, ho...
# 1                        racism, machismo, animal abuse
# 2     machismo, racism, global warming, animal abuse...
# 3
# 4                                animal abuse, machismo
# ...                                                 ...
# 1495  machismo, animal abuse, xenophobia, global war...
# 1496  xenophobia, machismo, homophobia, racism, glob...
# 1497  machismo, animal abuse, racism, homophobia, xe...
# 1498  global warming, homophobia, machismo, xenophob...
# 1499                   xenophobia, animal abuse, racism
#
# [1500 rows x 19 columns]
